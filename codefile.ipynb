# %%
pip install selenium pandas webdriver-manager
# Out:
# Requirement already satisfied: selenium in c:\users\heram ramesh\anaconda3_new\lib\site-packages (4.34.0)
# Requirement already satisfied: pandas in c:\users\heram ramesh\anaconda3_new\lib\site-packages (2.1.4)
# Requirement already satisfied: webdriver-manager in c:\users\heram ramesh\anaconda3_new\lib\site-packages (4.0.2)
# Requirement already satisfied: urllib3~=2.4.0 in c:\users\heram ramesh\anaconda3_new\lib\site-packages (from urllib3[socks]~=2.4.0->selenium) (2.4.0)
# Requirement already satisfied: trio~=0.30.0 in c:\users\heram ramesh\anaconda3_new\lib\site-packages (from selenium) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.12.2 in c:\users\heram ramesh\anaconda3_new\lib\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2025.4.26 in c:\users\heram ramesh\anaconda3_new\lib\site-packages (from selenium) (2025.4.26)
# Requirement already satisfied: typing_extensions~=4.14.0 in c:\users\heram ramesh\anaconda3_new\lib\site-packages (from selenium) (4.14.0)
# Requirement already satisfied: websocket-client~=1.8.0 in c:\users\heram ramesh\anaconda3_new\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\users\heram ramesh\anaconda3_new\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\heram ramesh\anaconda3_new\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\heram ramesh\anaconda3_new\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\heram ramesh\anaconda3_new\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: requests in c:\users\heram ramesh\anaconda3_new\lib\site-packages (from webdriver-manager) (2.32.3)
# Requirement already satisfied: python-dotenv in c:\users\heram ramesh\anaconda3_new\lib\site-packages (from webdriver-manager) (0.21.0)
# Requirement already satisfied: packaging in c:\users\heram ramesh\anaconda3_new\lib\site-packages (from webdriver-manager) (24.1)
# Requirement already satisfied: six>=1.5 in c:\users\heram ramesh\anaconda3_new\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\heram ramesh\anaconda3_new\lib\site-packages (from trio~=0.30.0->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\heram ramesh\anaconda3_new\lib\site-packages (from trio~=0.30.0->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\heram ramesh\anaconda3_new\lib\site-packages (from trio~=0.30.0->selenium) (3.7)
# Requirement already satisfied: outcome in c:\users\heram ramesh\anaconda3_new\lib\site-packages (from trio~=0.30.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\heram ramesh\anaconda3_new\lib\site-packages (from trio~=0.30.0->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\heram ramesh\anaconda3_new\lib\site-packages (from trio~=0.30.0->selenium) (1.17.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\heram ramesh\anaconda3_new\lib\site-packages (from trio-websocket~=0.12.2->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\heram ramesh\anaconda3_new\lib\site-packages (from urllib3[socks]~=2.4.0->selenium) (1.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\heram ramesh\anaconda3_new\lib\site-packages (from requests->webdriver-manager) (3.3.2)
# Requirement already satisfied: pycparser in c:\users\heram ramesh\anaconda3_new\lib\site-packages (from cffi>=1.14->trio~=0.30.0->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\heram ramesh\anaconda3_new\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\Heram
# [nltk_data]     Ramesh\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
# data scraping

import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import re

# Setup WebDriver
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# IMDb URL
base_url = "https://www.imdb.com/search/title/?genres=drama&start={}&explore=title_type,genres"

movie_names = []
storylines = []

# Start from page 1
start = 1

while True:
    url = base_url.format(start)
    print(f"Scraping: {url}")
    driver.get(url)
    time.sleep(3)

    # Find all movie containers on current page
    movies = driver.find_elements(By.XPATH, '//li[@class="ipc-metadata-list-summary-item"]')

    # If no movies found, we reached the last page → break loop
    if not movies:
        print("Reached the end of pages.")
        break

    for movie in movies:
        # Extract movie title
        try:
            title_text = movie.find_element(By.XPATH, './/h3[contains(@class,"ipc-title__text")]').text
            # Remove number prefix (e.g., "1. The Shawshank Redemption" → "The Shawshank Redemption")
            title = re.sub(r"^\d+\.\s*", "", title_text)
        except:
            title = "N/A"

        # Extract storyline / description
        try:
            storyline = movie.find_element(By.XPATH, './/div[contains(@class,"ipc-html-content-inner-div")]').text
        except:
            storyline = "N/A"

        movie_names.append(title)
        storylines.append(storyline)

    # Go to next page
    start += 50

# Save all scraped data into CSV
df = pd.DataFrame({"Movie Name": movie_names, "Storyline": storylines})
df.to_csv("imdb_all_movies_storylines.csv", index=False, encoding="utf-8")
print(f"✅ Scraped {len(df)} movies successfully!")

driver.quit()
# Out:
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=1&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=51&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=101&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=151&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=201&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=251&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=301&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=351&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=401&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=451&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=501&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=551&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=601&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=651&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=701&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=751&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=801&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=851&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=901&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=951&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=1001&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=1051&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=1101&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=1151&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=1201&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=1251&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=1301&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=1351&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=1401&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=1451&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=1501&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=1551&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=1601&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=1651&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=1701&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=1751&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=1801&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=1851&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=1901&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=1951&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=2001&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=2051&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=2101&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=2151&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=2201&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=2251&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=2301&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=2351&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=2401&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=2451&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=2501&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=2551&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=2601&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=2651&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=2701&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=2751&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=2801&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=2851&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=2901&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=2951&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=3001&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=3051&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=3101&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=3151&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=3201&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=3251&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=3301&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=3351&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=3401&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=3451&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=3501&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=3551&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=3601&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=3651&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=3701&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=3751&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=3801&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=3851&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=3901&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=3951&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start
&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=21151&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=21201&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=21251&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=21301&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=21351&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=21401&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=21451&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=21501&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=21551&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=21601&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=21651&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=21701&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=21751&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=21801&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=21851&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=21901&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=21951&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=22001&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=22051&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=22101&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=22151&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=22201&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=22251&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=22301&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=22351&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=22401&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=22451&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=22501&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=22551&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=22601&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=22651&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=22701&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=22751&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=22801&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=22851&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=22901&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=22951&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=23001&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=23051&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=23101&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=23151&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=23201&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=23251&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=23301&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=23351&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=23401&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=23451&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=23501&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=23551&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=23601&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=23651&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=23701&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=23751&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=23801&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=23851&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=23901&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=23951&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=24001&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=24051&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=24101&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=24151&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=24201&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=24251&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=24301&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=24351&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=24401&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=24451&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=24501&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=24551&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=24601&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=24651&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=24701&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=24751&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=24801&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=24851&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=24901&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=24951&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=25001&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=25051&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=25101&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=25151&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=25201&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=25251&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=25301&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=25351&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=25401&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=25451&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=25501&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=25551&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=25601&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=25651&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=25701&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=25751&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=25801&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=25851&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=25901&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=25951&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=26001&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=26051&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=26101&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=26151&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=26201&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=26251&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=26301&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=26351&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=26401&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=26451&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=26501&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=26551&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=26601&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=26651&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=26701&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=26751&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=26801&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=26851&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=26901&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=26951&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=27001&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=27051&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=27101&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=27151&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=27201&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=27251&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=27301&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=27351&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=27401&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=27451&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=27501&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=27551&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=27601&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=27651&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=27701&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=27751&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=27801&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=27851&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=27901&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=27951&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=28001&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=28051&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=28101&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=28151&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=28201&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=28251&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=28301&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=28351&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=28401&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=28451&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=28501&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=28551&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=28601&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=28651&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=28701&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=28751&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=28801&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=28851&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=28901&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=28951&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=29001&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=29051&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=29101&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=29151&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=29201&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=29251&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=29301&explore=title_type,genres
# Scraping: https://www.imdb.com/search/title/?genres=drama&start=29351&explore=title_type,genres
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 26
#      24 url = base_url.format(start)
#      25 print(f"Scraping: {url}")
# ---> 26 driver.get(url)
#      27 time.sleep(3)
#      29 # Find all movie containers on current page
#
# File c:\Users\Heram Ramesh\anaconda3_new\Lib\site-packages\selenium\webdriver\remote\webdriver.py:479, in WebDriver.get(self, url)
#     461 def get(self, url: str) -> None:
#     462     """Navigate the browser to the specified URL in the current window or
#     463     tab.
#     464
#    (...)
#     477     >>> driver.get("https://example.com")
#     478     """
# --> 479     self.execute(Command.GET, {"url": url})
#
# File c:\Users\Heram Ramesh\anaconda3_new\Lib\site-packages\selenium\webdriver\remote\webdriver.py:451, in WebDriver.execute(self, driver_command, params)
#     448     elif "sessionId" not in params:
#     449         params["sessionId"] = self.session_id
# --> 451 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     453 if response:
#     454     self.error_handler.check_response(response)
#
# File c:\Users\Heram Ramesh\anaconda3_new\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:404, in RemoteConnection.execute(self, command, params)
#     402 trimmed = self._trim_large_entries(params)
#     403 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 404 return self._request(command_info[0], url, body=data)
#
# File c:\Users\Heram Ramesh\anaconda3_new\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:428, in RemoteConnection._request(self, method, url, body)
#     425     body = None
#     427 if self._client_config.keep_alive:
# --> 428     response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#     429     statuscode = response.status
#     430 else:
#
# File c:\Users\Heram Ramesh\anaconda3_new\Lib\site-packages\urllib3\_request_methods.py:143, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     135     return self.request_encode_url(
#     136         method,
#     137         url,
#    (...)
#     140         **urlopen_kw,
#     141     )
#     142 else:
# --> 143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File c:\Users\Heram Ramesh\anaconda3_new\Lib\site-packages\urllib3\_request_methods.py:278, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     274     extra_kw["headers"].setdefault("Content-Type", content_type)
#     276 extra_kw.update(urlopen_kw)
# --> 278 return self.urlopen(method, url, **extra_kw)
#
# File c:\Users\Heram Ramesh\anaconda3_new\Lib\site-packages\urllib3\poolmanager.py:443, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     441     response = conn.urlopen(method, url, **kw)
#     442 else:
# --> 443     response = conn.urlopen(method, u.request_uri, **kw)
#     445 redirect_location = redirect and response.get_redirect_location()
#     446 if not redirect_location:
#
# File c:\Users\Heram Ramesh\anaconda3_new\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\Heram Ramesh\anaconda3_new\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\Heram Ramesh\anaconda3_new\Lib\site-packages\urllib3\connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\Heram Ramesh\anaconda3_new\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File c:\Users\Heram Ramesh\anaconda3_new\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File c:\Users\Heram Ramesh\anaconda3_new\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File c:\Users\Heram Ramesh\anaconda3_new\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
#Preprocessing

import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Download required NLTK data (including the new punkt_tab)
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('punkt_tab')

# ✅ Load the correct dataset
df = pd.read_csv("imdb_movies_storylines.csv")

# Initialize lemmatizer and stopwords
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def clean_text(text):
    # Remove non-alphabetic characters
    text = re.sub(r'[^a-zA-Z]', ' ', str(text))
    # Lowercase conversion
    text = text.lower()
    # Tokenization
    tokens = nltk.word_tokenize(text)
    # Remove stopwords & lemmatize
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
    return " ".join(tokens)

# Apply text cleaning on storylines
df["Cleaned_Storyline"] = df["Storyline"].apply(clean_text)

# Save cleaned dataset
df.to_csv("imdb_movies_storylines_cleaned.csv", index=False)

print("✅ Preprocessing completed successfully!")
df.head()
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Heram
# [nltk_data]     Ramesh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Heram
# [nltk_data]     Ramesh\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\Heram
# [nltk_data]     Ramesh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Heram
# [nltk_data]     Ramesh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# ✅ Preprocessing completed successfully!
#              Movie Name                                          Storyline  \
# 0  Dexter: Resurrection  Dexter Morgan awakens from a coma and sets out...
# 1               Hostage  When the PM's husband is kidnapped and the vis...
# 2         F1: The Movie  A Formula One driver comes out of retirement t...
# 3          Eenie Meanie  A reformed teenage getaway driver is dragged b...
# 4               Fallout  In a future, post-apocalyptic Los Angeles brou...
#
#                                    Cleaned_Storyline
# 0  dexter morgan awakens coma set new york city d...
# 1  pm husband kidnapped visiting french president...
# 2  formula one driver come retirement mentor team...
# 3  reformed teenage getaway driver dragged back u...
# 4  future post apocalyptic los angeles brought nu...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Load the cleaned dataset
df = pd.read_csv("imdb_movies_storylines_cleaned.csv")

# Initialize TF-IDF Vectorizer
tfidf = TfidfVectorizer(stop_words="english")

# Convert cleaned storylines into TF-IDF matrix
tfidf_matrix = tfidf.fit_transform(df["Cleaned_Storyline"])

print("✅ TF-IDF Matrix Shape:", tfidf_matrix.shape)
# Out:
# ✅ TF-IDF Matrix Shape: (2000, 572)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Compute similarity matrix
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

print("✅ Cosine Similarity Matrix Shape:", cosine_sim.shape)
# Out:
# ✅ Cosine Similarity Matrix Shape: (2000, 2000)

# %%
def recommend_movies(title, df, cosine_sim):
    # Check if the movie exists
    if title.lower() not in df["Movie Name"].str.lower().values:
        return f"❌ Movie '{title}' not found in the dataset."

    # Get index of the movie
    idx = df[df["Movie Name"].str.lower() == title.lower()].index[0]

    # Get similarity scores for the selected movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort movies by similarity score (descending)
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get top 5 recommended movie indices (excluding itself)
    top_indices = [i[0] for i in sim_scores[1:6]]

    # Return top 5 movie names
    return df["Movie Name"].iloc[top_indices].tolist()
